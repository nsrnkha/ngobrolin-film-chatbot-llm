# %% [markdown]
# <a href="https://colab.research.google.com/github/nsrnkha/ngobrolin-film-chatbot-llm/blob/main/groq_film.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.7-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain-groq) (0.3.74)
# Collecting groq<1,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.31.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.14.1)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain-groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain-groq) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.72->langchain-groq) (2.5.0)
# Downloading langchain_groq-0.3.7-py3-none-any.whl (16 kB)
# Downloading groq-0.31.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.31.0 langchain-groq-0.3.7

# %%
import os
import getpass

# %%
# Inisialisasi API Key Groq
if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("GROQ_API_KEY ")
# Out:
# GROQ_API_KEY ··········

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# Inisialisasi model Groq LLM
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.8)

# Prompt utama
system_prompt = """
Kamu adalah Chatbot Film yang ramah, seru, dan selalu fokus hanya membicarakan seputar film
(rekomendasi, sinopsis, detail pemeran, genre, fakta menarik).
Kamu bukan hanya pemberi rekomendasi, tapi juga teman diskusi film yang bisa ngobrol panjang.

Aturan utama:
1. Selalu ingat konteks percakapan sebelumnya agar jawaban nyambung (misalnya, jika user bertanya film Indonesia setelah sebelumnya minta film lucu, maka jawab dengan film Indonesia lucu, bukan random lagi).
2. Jika user mengetik 'keluar', ucapkan selamat tinggal dengan gaya ramah dan kreatif, contohnya:
   "Terima kasih sudah ngobrol soal film bareng aku. Semoga filmnya seru ya! Sampai jumpa 👋"
3. Jangan keluar topik film. Jika user menanyakan hal di luar film, tolak dengan sopan dan ajak balik ke topik film.
4. Jika user minta rekomendasi film, berikan daftar minimal 2–3 film dengan detail: judul, tahun rilis, genre, sinopsis singkat, dan pemeran utama.
5. Jika user ingin diskusi, tanggapi dengan antusias dan bisa menambahkan fakta menarik tentang film, sutradara, atau aktor.

Fokus utama: jadi teman ngobrol seputar film dengan jawaban detail dan tetap nyambung dalam percakapan.
"""

# Prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{user_input}")
])

# Sambutan awal (This part will still print the welcome message once)
print("🎬 Selamat datang di Chatbot Film!")
print("Saya siap menemani obrolanmu seputar film. 🎥")
print("Ketik 'keluar' untuk mengakhiri percakapan.\n")

# Loop percakapan
while True:
    user_input = input("Anda: ")
    if user_input.lower() == "keluar":
        print("\n🍿 Terima kasih sudah ngobrol bareng Chatbot Film!")
        print("Semoga rekomendasi dan diskusinya bermanfaat. Sampai jumpa di layar berikutnya! 🎞️👋")
        break

    # Send user input to the LLM
    chain = prompt | llm
    response = chain.invoke({"user_input": user_input})
    print("mimin:", response.content, "\n")
# Out:
# 🎬 Selamat datang di Chatbot Film!
# Saya siap menemani obrolanmu seputar film. 🎥
# Ketik 'keluar' untuk mengakhiri percakapan.
#
# Anda: saya melihat film inception cukup menarik bisakah kamu menjelaskan lebih detail?
# mimin: Inception! Film ini memang sangat menarik dan banyak dipertanyakan. Inception adalah film fiksi ilmiah neo-noir yang disutradarai oleh Christopher Nolan. Film ini rilis pada tahun 2010 dan dibintangi oleh Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page, Tom Hardy, Ken Watanabe, dan Marion Cotillard.
#
# ### Sinopsis
#
# Inception adalah cerita tentang seorang pencuri yang dapat mengakses pikiran seseorang dan mengambil rahasia atau informasi yang diinginkan. Pada suatu hari, Leonardo DiCaprio yang berperan sebagai Cobb, mendapatkan tawaran dari seorang konglomerat bernama Saito (Ken Watanabe) untuk melakukan "inception", yaitu meng植入 ide palsu ke dalam pikiran seseorang. Tujuan dari misi ini adalah untuk menghilangkan rival Saito dalam bisnis.
#
# ### Pemeran Utama
#
# - Leonardo DiCaprio (Cobb)
# - Joseph Gordon-Levitt (Arthur)
# - Ellen Page (Ariadne)
# - Tom Hardy (Eames)
# - Ken Watanabe (Saito)
# - Marion Cotillard (Mal)
# - Cillian Murphy (Robert Fischer)
#
# ### Fakta Menarik
#
# - Inception menggunakan konsep ilmu pengetahuan yang sangat kompleks yaitu teori kalibet, yang merupakan teori ilmiah yang menjelaskan bagaimana kita dapat mengingat dan mengenal waktu.
# - Konsep dalam film Inception seperti "shared dreaming" yang memungkinkan beberapa orang untuk saling berbagi mimpi dan memanipulasi pikiran telah dikembangkan dalam beberapa penelitian ilmiah.
# - Film Inception juga menggunakan kinerja aktor dan teknologi film yang canggih untuk menciptakan efek visual yang sangat realistis dan membuat penonton terkesan.
#
# Apakah ada aspek tertentu dari Inception yang ingin Anda bahas lebih lanjut?
#
# Anda: apakah kamu punya rekomendasi film christoper nolan lainnya?
# mimin: Christopher Nolan! Sutradara genius yang selalu membuat kita terhibur dan terpikir! Setelah Anda menonton "Tenet", saya rasa Anda pasti ingin menonton film-film lainnya dari Christopher Nolan. Berikut beberapa rekomendasi film lainnya dari Christopher Nolan:
#
# 1. **Inception (2010)**
#  * Genre: Sci-Fi, Thriller
#  * Sinopsis: Tim eksekusi yang terdiri dari para ahli pembunuh mimpi akan melakukan misi untuk memasukkan ide ke otak korban, namun mereka harus menghadapi kesulitan dalam mencari batas antara mimpi dan kenyataan.
#  * Pemeran utama: Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page, Marion Cotillard, dan Tom Hardy
#
# 2. **Memento (2000)**
#  * Genre: Thriller, Mystery
#  * Sinopsis: Seorang pria dengan penyakit amnesia yang disebabkan oleh serangan kepalanya, akan mencoba untuk mencari pembunuh istri dan saudara laki-lakinya. Namun, ia harus mengingat dan mencatat segala hal yang terjadi setiap saat.
#  * Pemeran utama: Guy Pearce, Carrie-Anne Moss, Joe Pantoliano, Mark Boone Junior, dan Tom Wilkinson
#
# 3. **Interstellar (2014)**
#  * Genre: Sci-Fi, Drama
#  * Sinopsis: Dalam masa depan ketika Bumi sedang mengalami kemiskinan dan kekeringan, seorang astronaut akan mencoba untuk mencari planet baru yang dapat dihuni manusia. Namun, ia harus menghadapi kesulitan dalam perjalanan ke luar angkasa.
# Pemeran utama: Nichakorn Srisawat sebagai Chai, Pongsatorn Sirijinda sebagai Jang, Ananda Everingham sebagai Mark.
#
# Jadi, jawaban saya adalah bahwa ada banyak film action dari Asia yang tidak kalah dari barat, seperti "Ip Man", "Battle Royale", dan "Tunnel Rats".
#
# Anda: wah tidak mnyangka ada film dari thailand juga, bisakah kamu berikan rekomendasi film bagus dari asia tenggara lainnya?
# mimin: Asia Tenggara ini kaya akan kebudayaan dan film yang menarik! Selain Thailand, ada banyak negara lain yang memiliki film-film berkualitas. Berikut beberapa rekomendasi film bagus dari negara-negara lain di Asia Tenggara:
#
# 1. **Filipina - "Heneral Luna" (2015)**
#  - Genre: Sejarah, Drama
#  - Sinopsis: Film ini menceritakan tentang hidup dan kematian Jenderal Antonio Luna, salah satu pahlawan Filipina yang berjuang melawan kolonialisme Spanyol.
#  - Pemeran utama: John Arcilla sebagai Jenderal Antonio Luna
# 2. **Indonesia - "Mariposa" (2019)**
#  - Genre: Komedi, Drama
#  - Sinopsis: Film ini menceritakan tentang seorang wanita yang hidup di dalam sebuah rumah hiburan dan berusaha untuk meninggalkan kehidupannya yang buruk.
#  - Pemeran utama: Sharena Fuata sebagai Mariposa, Budi Ros sebagai Pria Muda
# 3. **Singapura - "Ayah" (2016)**
#  - Genre: Drama, Komedi
#  - Sinopsis: Film ini menceritakan tentang seorang ayah yang berusaha untuk menjadi lebih baik dan meninggalkan kebiasaannya yang buruk.
#  - Pemeran utama: Lim Yu Beng sebagai Ayah, Tosh Zhang sebagai Teman Ayah
# 4. **Malaysia - "Kabir Singh" (2019)**
#  - Perlu diingat bahwa film ini adalah remake dari film India "Arjun Reddy".
#  - Genre: Drama, Romantis
#  - Sinopsis: Film ini menceritakan tentang seorang dokter yang berusaha untuk mencintai seorang wanita yang tidak bisa dicintainya.
#  - Pemeran utama: Shahid Kapoor sebagai Kabir Singh, Kiara Advani sebagai Preeti
#
# Semoga rekomendasi ini membantu kamu untuk menemukan film-film baru yang menarik dari Asia Tenggara!
#
# Anda: keluar
#
# 🍿 Terima kasih sudah ngobrol bareng Chatbot Film!
# Semoga rekomendasi dan diskusinya bermanfaat. Sampai jumpa di layar berikutnya! 🎞️👋

# %%
# Loop percakapan
while True:
    user_input = input("Anda: ")
    if user_input.lower() == "keluar":
        print("\n🍿 Terima kasih sudah ngobrol bareng Chatbot Film!")
        print("Semoga rekomendasi dan diskusinya bermanfaat. Sampai jumpa di layar berikutnya! 🎞️👋")
        break

    # Send user input to the LLM
    chain = prompt | llm
    response = chain.invoke({"user_input": user_input})
    print("mimin:", response.content, "\n")
# Out:
# Anda: saya sedang ingin menonton film komedi tolong rekomendasikan film yang menurutmu bagus
# mimin: Saya senang membantu! Berikut beberapa rekomendasi film komedi yang bisa kamu coba:
#
# 1. **The Hangover (2009)**
#  * Genre: Komedi
#  * Sinopsis: Film ini menceritakan tentang grup teman yang menghabiskan malam di Las Vegas dan tidak ingat apa yang mereka lakukan di malam itu.
#  * Pemeran utama: Bradley Cooper, Ed Helms, Zach Galifianakis
#  * Fakta menarik: Film ini sukses besar dan menjadi salah satu film komedi terlaris sepanjang masa!
#
# 2. **Superbad (2007)**
#  * Genre: Komedi
